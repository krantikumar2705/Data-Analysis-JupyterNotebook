# %% [markdown]
# # 1. Import required libraries and read the dataset

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\lenovo\Desktop\python new projecy\honeyproduction.csv")

# %%
data.head()
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998

# %% [markdown]
# # 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features.

# %%
data.shape
# Out:
# (626, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.3+ KB

# %%
data.dtypes
# Out:
# state           object
# numcol         float64
# yieldpercol      int64
# totalprod      float64
# stocks         float64
# priceperlb     float64
# prodvalue      float64
# year             int64
# dtype: object

# %%
data.tail()
# Out:
#     state   numcol  yieldpercol  totalprod     stocks  priceperlb  prodvalue  \
# 621    VA   4000.0           41   164000.0    23000.0        3.77   618000.0
# 622    WA  62000.0           41  2542000.0  1017000.0        2.38  6050000.0
# 623    WV   6000.0           48   288000.0    95000.0        2.91   838000.0
# 624    WI  60000.0           69  4140000.0  1863000.0        2.05  8487000.0
# 625    WY  50000.0           51  2550000.0   459000.0        1.87  4769000.0
#
#      year
# 621  2012
# 622  2012
# 623  2012
# 624  2012
# 625  2012

# %%
data.describe()
# Out:
#               numcol  yieldpercol     totalprod        stocks  priceperlb  \
# count     626.000000   626.000000  6.260000e+02  6.260000e+02  626.000000
# mean    60284.345048    62.009585  4.169086e+06  1.318859e+06    1.409569
# std     91077.087231    19.458754  6.883847e+06  2.272964e+06    0.638599
# min      2000.000000    19.000000  8.400000e+04  8.000000e+03    0.490000
# 25%      9000.000000    48.000000  4.750000e+05  1.430000e+05    0.932500
# 50%     26000.000000    60.000000  1.533000e+06  4.395000e+05    1.360000
# 75%     63750.000000    74.000000  4.175250e+06  1.489500e+06    1.680000
# max    510000.000000   136.000000  4.641000e+07  1.380000e+07    4.150000
#
#           prodvalue         year
# count  6.260000e+02   626.000000
# mean   4.715741e+06  2004.864217
# std    7.976110e+06     4.317306
# min    1.620000e+05  1998.000000
# 25%    7.592500e+05  2001.000000
# 50%    1.841500e+06  2005.000000
# 75%    4.703250e+06  2009.000000
# ...

# %% [markdown]
# # . Display the percentage distribution of the data in each year using the pie chart.

# %%
y = data['year'].unique()

# %%
plt.pie(x,labels=y,autopct = "%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1c8f3af2e10>,
# ...
#  [Text(1.0867325991486694, 0.1703298504302093, '1998'),
#   Text(0.9940343732259835, 0.4710580270468027, '1999'),
#   Text(0.8312151721577545, 0.7204729957290245, '2000'),
#   Text(0.5990077948625714, 0.9225994047764609, '2001'),
#   Text(0.21118329593108265, 1.0795376860117876, '2002'),
#   Text(-0.3428638904612501, 1.045200627926417, '2003'),
#   Text(-0.7854155098500246, 0.7701444519614655, '2004'),
#   Text(-1.0155122392416722, 0.4227704956005859, '2005'),
#   Text(-1.098317936816498, 0.06080879596860649, '2006'),
#   Text(-1.0557913775775254, -0.30871437775547705, '2007'),
#   Text(-0.8406560652814165, -0.7094345494163412, '2008'),
#   Text(-0.4257622560135168, -1.0142615547058267, '2009'),
#   Text(0.13873616679261877, -1.0912159621375095, '2010'),
#   Text(0.7069560153180483, -0.842741474240842, '2011'),
#   Text(1.0512759101806457, -0.32375756465888983, '2012')],
#  [Text(0.5927632358992742, 0.09290719114375051, '4.9%'),
# ...

# %%
value_by_year = data.groupby('year')["prodvalue"].sum()
x=value_by_year

# %% [markdown]
# # 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
sns.displot(data['priceperlb'])
plt.title(" distribution of the variable")
# Out:
# Text(0.5, 1.0, ' distribution of the variable')

# %% [markdown]
# # 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
plt.scatter(data['numcol'], data['prodvalue'])
plt.title("Scatter plot of numcol and prodval")
plt.xlabel("numcol")
plt.ylabel("prodvalue")
# Out:
# Text(0, 0.5, 'prodvalue')

# %% [markdown]
#  We can simply say that there is correlation between both the variables _ There is positive correlation between both the variables _ That simply means that if one variable is increasing then other will also increase _ And if one variable is decreasing then other will also decrease _ Any impact on any one variable will definitely effect the other variable _They both are positively correlated

# %% [markdown]
# # 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
plt.boxplot(data["year"],showmeans=True)
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Boxplot of Year')
# Out:
# Text(0.5, 1.0, 'Boxplot of Year')

# %%
plt.boxplot(data["prodvalue"],showmeans=True)
plt.title(" numerical variable 'prodvalue")
plt.ylabel('prodvalue')
# Out:
# Text(0, 0.5, 'prodvalue')

# %% [markdown]
# # 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years
# using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
sns.pairplot(data)

# %% [markdown]
# # 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
column = ['numcol','yieldpercol','totalprod','stocks','priceperlb','prodvalue']
column_for_corr = data[column]

correalation = column_for_corr.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(correalation,annot=True,cmap = 'pink')
# Out:
# <Axes: >
